# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
df=pd.read_csv("/content/drive/MyDrive/SBI Dataset.csv")
pickle.dump(df,open('df.pkl','wb'))

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  03-01-2000  22.267092  22.988886  22.101974  22.988886  15.844801
# 1  04-01-2000  22.988886  24.720245  22.535995  24.446625  16.849524
# 2  05-01-2000  23.493668  24.974997  23.116261  23.441774  16.156942
# 3  06-01-2000  23.776726  25.286358  23.776726  24.625893  16.973083
# 4  07-01-2000  24.673071  26.409147  24.059780  25.786425  17.772966
#
#        Volume
# 0  25152894.0
# 1  47648560.0
# 2  36396207.0
# 3  70573968.0
# 4  83453217.0

# %%
df.shape
# Out:
# (6094, 7)

# %%
df['Date']=pd.to_datetime(df['Date'], format='%d-%m-%Y')

# %%
df['year']=df['Date'].dt.year
df['month']=df['Date'].dt.month
df['day']=df['Date'].dt.day

# %%
df.drop(columns='Date',inplace=True)

# %%
df.head()
# Out:
#         Open       High        Low      Close  Adj Close      Volume  year  \
# 0  22.267092  22.988886  22.101974  22.988886  15.844801  25152894.0  2000
# 1  22.988886  24.720245  22.535995  24.446625  16.849524  47648560.0  2000
# 2  23.493668  24.974997  23.116261  23.441774  16.156942  36396207.0  2000
# 3  23.776726  25.286358  23.776726  24.625893  16.973083  70573968.0  2000
# 4  24.673071  26.409147  24.059780  25.786425  17.772966  83453217.0  2000
#
#    month  day
# 0      1    3
# 1      1    4
# 2      1    5
# 3      1    6
# 4      1    7

# %%
df.isnull().sum()
# Out:
# Open         9
# High         9
# Low          9
# Close        9
# Adj Close    9
# Volume       9
# year         0
# month        0
# day          0
# dtype: int64

# %%
df[df['Open'].isnull()]
# Out:
#       Open  High  Low  Close  Adj Close  Volume  year  month  day
# 1125   NaN   NaN  NaN    NaN        NaN     NaN  2004      4   26
# 1247   NaN   NaN  NaN    NaN        NaN     NaN  2004     10   13
# 2563   NaN   NaN  NaN    NaN        NaN     NaN  2010      2    6
# 3041   NaN   NaN  NaN    NaN        NaN     NaN  2012      1    7
# 3080   NaN   NaN  NaN    NaN        NaN     NaN  2012      3    3
# 3210   NaN   NaN  NaN    NaN        NaN     NaN  2012      9    8
# 3252   NaN   NaN  NaN    NaN        NaN     NaN  2012     11   11
# 3589   NaN   NaN  NaN    NaN        NaN     NaN  2014      3   22
# 3818   NaN   NaN  NaN    NaN        NaN     NaN  2015      2   28

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6085 entries, 0 to 6093
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       6085 non-null   float64
#  1   High       6085 non-null   float64
#  2   Low        6085 non-null   float64
#  3   Close      6085 non-null   float64
#  4   Adj Close  6085 non-null   float64
#  5   Volume     6085 non-null   float64
#  6   year       6085 non-null   int32
#  7   month      6085 non-null   int32
#  8   day        6085 non-null   int32
# dtypes: float64(6), int32(3)
# memory usage: 404.1 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  6085.000000  6085.000000  6085.000000  6085.000000  6085.000000
# mean    214.090751   216.911547   210.948042   213.830092   195.086130
# std     161.861630   163.432974   160.101529   161.764701   159.134943
# min      13.478195    13.959390    13.214009    13.346102     9.638022
# 25%      77.934822    79.340668    76.330833    78.321663    62.041142
# 50%     204.809998   207.800003   201.235001   204.770004   180.137939
# 75%     279.850006   283.350006   276.000000   279.515015   258.136292
# max     835.000000   839.650024   825.000000   831.450012   818.349976
#
#              Volume         year        month          day
# count  6.085000e+03  6085.000000  6085.000000  6085.000000
# mean   2.328283e+07  2011.582087     6.459326    15.765160
# std    1.847335e+07     7.080595     3.449675     8.775858
# min    0.000000e+00  2000.000000     1.000000     1.000000
# 25%    1.225304e+07  2005.000000     3.000000     8.000000
# 50%    1.846845e+07  2012.000000     6.000000    16.000000
# 75%    2.851413e+07  2018.000000     9.000000    23.000000
# max    2.626771e+08  2024.000000    12.000000    31.000000

# %%
sns.heatmap(df.corr(),annot=True, cmap='coolwarm',cbar=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='Open',y='Close',data=df)
# Out:
# <Axes: xlabel='Open', ylabel='Close'>

# %%
# sns.pairplot(df)

# %%
for i in df.columns:
  plt.figure(figsize=(10,5))
  sns.distplot(df[i])
  plt.title(i)
  plt.show()
# Out:
# <ipython-input-20-3288f212be01>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-20-3288f212be01>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-20-3288f212be01>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-20-3288f212be01>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-20-3288f212be01>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-20-3288f212be01>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-20-3288f212be01>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-20-3288f212be01>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-20-3288f212be01>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])

# %%
df.drop(columns='Adj Close',inplace=True)

# %%
x=df.drop(columns='Close')
y=df['Close']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=34)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.compose import ColumnTransformer

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(x_train,y_train), rf.score(x_test,y_test)
# Out:
# (0.9999662812661004, 0.9997406997332762)

# %%
y_pred=rf.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9997406997332762

# %%
df
# Out:
#             Open        High         Low       Close      Volume  year  month  \
# 0      22.267092   22.988886   22.101974   22.988886  25152894.0  2000      1
# 1      22.988886   24.720245   22.535995   24.446625  47648560.0  2000      1
# 2      23.493668   24.974997   23.116261   23.441774  36396207.0  2000      1
# 3      23.776726   25.286358   23.776726   24.625893  70573968.0  2000      1
# 4      24.673071   26.409147   24.059780   25.786425  83453217.0  2000      1
# ...          ...         ...         ...         ...         ...   ...    ...
# 6089  821.000000  825.299988  818.049988  820.299988   9755062.0  2024      5
# 6090  825.299988  826.150024  797.349976  811.950012  20536990.0  2024      5
# 6091  814.500000  822.450012  811.200012  817.849976  12492509.0  2024      5
# 6092  821.000000  836.299988  819.599976  830.650024  14037801.0  2024      5
# 6093  826.549988  826.650024  813.549988  818.349976  14931225.0  2024      5
#
#       day
# 0       3
# 1       4
# 2       5
# 3       6
# 4       7
# ...   ...
# 6089   15
# 6090   16
# 6091   17
# 6092   21
# 6093   22
#
# [6085 rows x 8 columns]

# %%
import pickle
pickle.dump(rf,open('model.pkl','wb'))
